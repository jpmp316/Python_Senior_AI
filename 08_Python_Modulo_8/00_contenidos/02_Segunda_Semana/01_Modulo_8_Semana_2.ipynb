# %% [markdown]
# ## **Prompt para Cursor AI — Clase 2: Modularización de componentes y refactor con IA**
#
# > **Rol:** Eres un asistente experto en desarrollo frontend con **React 18, Vite 5 y Tailwind CSS v4**, especializado en **refactorización, arquitectura limpia y documentación técnica**.
# > Tu tarea es **modularizar y documentar completamente** una interfaz React existente de un sistema de tareas, aplicando los principios de **separación de lógica y presentación**, **reutilización de componentes**, y **diseño responsivo moderno** con TailwindCSS.
#
# ---
#
# ### **Objetivos de la clase**
#
# 1. Separar la lógica y la interfaz (UI) en componentes reutilizables.
# 2. Mejorar la organización, estructura y mantenibilidad del código.
# 3. Aplicar refactorización con asistencia de IA para lograr código limpio y documentado.
# 4. Implementar diseño responsivo básico con TailwindCSS.
#
# ---
#
# ### **Actividades solicitadas**
#
# Refactoriza el proyecto para que contenga los siguientes componentes dentro de `src/components/`:
#
# | **Componente** | **Función**         | **Descripción técnica**                                                                                          |
# | -------------- | ------------------- | ---------------------------------------------------------------------------------------------------------------- |
# | `Header.jsx`   | Cabecera principal  | Muestra el título del sistema y un subtítulo o mensaje de bienvenida.                                            |
# | `TaskList.jsx` | Contenedor de lista | Renderiza el listado de tareas dinámicamente a partir de un arreglo.                                             |
# | `TaskItem.jsx` | Tarea individual    | Componente individual reutilizable para cada tarea. Debe recibir `props` como `title`, `completed` y `onToggle`. |
# | `Footer.jsx`   | Pie de página       | Muestra información institucional o de autoría (por ejemplo, “Sistema de Tareas © 2025”).                        |
#
# ---
#
# ### **Requerimientos técnicos**
#
# 1. **React funcional con Hooks (`useState`, `useEffect`)**.
# 2. **Tailwind CSS v4** para todos los estilos (no CSS externo).
# 3. Código documentado con comentarios en formato JSDoc.
# 4. Seguir las normas:
#
#    * Airbnb JavaScript Style Guide.
#    * OWASP Secure Coding Practices (sin `eval`, ni `innerHTML`).
#    * Clean Code (funciones cortas, nombres claros, sin duplicación).
# 5. Implementar **diseño responsivo básico** (breakpoints `sm`, `md`, `lg`).
# 6. Evitar lógica repetida: la IA debe detectar patrones similares y abstraerlos en componentes.
#
# ---
#
# ### **Asistencia con IA**
#
# La IA debe:
#
# * Identificar elementos repetidos (por ejemplo, tarjetas o filas) y convertirlos en componentes reutilizables.
# * Refactorizar JSX y estructura de carpetas para mayor legibilidad.
# * Generar comentarios explicativos sobre la responsabilidad de cada componente.
# * Agregar documentación inline y un **resumen técnico al final del archivo principal (`App.jsx`)** explicando cómo se modularizó el sistema.
#
# ---
#
# ### **Documentación esperada**
#
# Cada componente debe incluir:
#
# 1. **Cabecera JSDoc** con descripción, props y autor.
# 2. **Comentarios inline** explicando decisiones clave.
# 3. Un bloque `/** IA Refactor Summary: … */` al final del archivo con un resumen de la mejora realizada.
#
# Ejemplo de cabecera:
#
# ```jsx
# /**
#  * TaskItem.jsx
#  * Componente reutilizable para representar una tarea individual.
#  * @param {string} title - Nombre de la tarea.
#  * @param {boolean} completed - Estado de la tarea.
#  * @param {function} onToggle - Callback para alternar estado.
#  * @returns {JSX.Element}
#  */
# ```
#
# ---
#
# ### **Resultado esperado**
#
# Un proyecto con estructura modular:
#
# ```
# src/
# ├── components/
# │   ├── Header.jsx
# │   ├── TaskList.jsx
# │   ├── TaskItem.jsx
# │   ├── Footer.jsx
# │
# ├── App.jsx
# └── main.jsx
# ```
#
# **Características del resultado:**
#
# * Código limpio, seguro y mantenible.
# * Documentación generada automáticamente.
# * Diseño visual equilibrado, moderno y responsivo.
# * Ejecutable sin errores con:
#
#   ```bash
#   npm run dev
#   ```
#
# ---
#
# ¿Quieres que te cree ahora una **versión extendida del prompt** que haga que Cursor también **genere automáticamente los tests unitarios (con Vitest + Testing Library)** para cada componente modularizado?
# Sería ideal como cierre de la Clase 2 o inicio de la Clase 3.

# %% [markdown]
# ## **Actividad Práctica – Búsqueda y aplicación de estilos Tailwind en React**
#
# ### Título:
#
# **"Mejora visual de la interfaz usando estilos TailwindCSS para React"**
#
# ---
#
# ### Instrucciones para el estudiante
#
# 1. **Investiga estilos y diseños avanzados de TailwindCSS aplicables a React.**
#
#    Puedes usar fuentes como:
#
#    * 📌 [https://tailwindcss.com/docs](https://tailwindcss.com/docs)
#    * 📌 [https://flowbite-react.com](https://flowbite-react.com)
#    * 📌 [https://www.hyperui.dev](https://www.hyperui.dev)
#    * 📌 [https://tailwindui.com](https://tailwindui.com) (si deseas explorar inspiración)
#    * 📌 “React Tailwind modern UI” en Google o Pinterest
#
# 2. **Elige al menos 3 mejoras visuales** que aplicarás sobre la página creada en clase (pueden ser colores, tipografía, sombras, autoría, hover, etc.).
#
# 3. **Modifica los componentes existentes** (`Header`, `TaskList`, `TaskItem`, `Footer` o `App.jsx`) con los nuevos estilos.
#
# 4. **Realiza las mejoras con criterio profesional de UI**, sin alterar la funcionalidad.
#
# 5. **Documenta los cambios realizados** en comentarios breves dentro del archivo (por ejemplo: `// Cambio de color de fondo para mejorar contraste visual`).
#
# 6. **Realiza un antes y después (captura o comentario del código previo y final).**
#
# 7. **Opcional (mejores estudiantes):** Usa IA (Cursor o CodeGPT) para sugerir estilos, indicando exactamente qué componente quieres mejorar.
#
# ---

# %% [markdown]
# # Mensaje para Linkedin
#
# 📊 Sistema de Gestión de Tareas - React Application
#
# He desarrollado una aplicación web para gestión de tareas implementando arquitectura de componentes con React y metodología utility-first con Tailwind CSS.
#
# 🏗️ Arquitectura implementada:
#
# • Componentes funcionales con hooks (useState, useEffect)
#
# • Props validation con PropTypes
#
# • Controlled forms pattern
#
# • Responsive design mobile-first
#
# • Component documentation con JSDoc
#
#
# 💻 Stack tecnológico:
# React.js • Tailwind CSS • JavaScript ES6+
#
# Esta práctica me permitió profundizar en conceptos como:
# ✓ Manejo de estado inmutable
# ✓ Ciclo de vida con useEffect
# ✓ Composición de componentes
# ✓ Diseño atómico con utility classes
#
# El proyecto continúa en evolución con nuevas funcionalidades planificadas.
#
# Código disponible bajo solicitud.
#
# #ReactJS #TailwindCSS #WebDevelopment #Frontend #JavaScript #ComponentArchitecture #ModernWeb #SoftwareDevelopment
#
# ### Subir la imagen del proyecto

# %% [markdown]
# ---
#
#
# # 🧪 PRÁCTICA – HTML + Tailwind
#
# ### Construcción de formulario empresarial en index.html siguiendo documentación Tailwind V3
#
# ---

# %% [markdown]
# #### OBJETIVO GENERAL
#
# Al finalizar la práctica, el estudiante será capaz de:
#
# ✔ Integrar **Tailwind CSS v3 vía Play CDN** y **Flowbite vía CDN**
#
# ✔ Construir la interfaz empresarial de agendamiento de cita (como tu imagen)
#
# ✔ Importar componentes desde la documentación oficial
#
# ✔ Integrar **layout, formulario, cards y botones** paso a paso
#
# ✔ Comprender cómo modificar estilos usando utilidades de Tailwind
#
# ---

# %% [markdown]
# #### 📂 ESTRUCTURA DE ARCHIVOS
#
# ```
# practica-flowbite/
# ├── index.html
# ```
#
# 💡 Solo trabajaremos sobre **index.html** utilizando **Live Server**.
#
# ---

# %% [markdown]
# App
#
# ![App](images/app.jpg)

# %% [markdown]
# # INICIO DE LA PRÁCTICA
#
# ## 1. CONFIGURACIÓN INICIAL
#
# ### 1.1 Crear archivo `index.html`

# %%
<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0" />
    <title>Document</title>
  </head>
  <body></body>
</html>

# %% [markdown]
# Ahora, integrar dentro de la etiqueta `<head> </head>` el script de Tailwind + el `link` de Flowbite:
#
# Script de Tailwind:
# ```
# https://v3.tailwindcss.com/docs/installation/play-cdn?
# ```
#
# link de Flowbite:
#
# ```
# https://flowbite.com/docs/getting-started/quickstart/
# ```

# %%
<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0" />
    <script src="https://cdn.tailwindcss.com"></script>
    <link
      href="https://cdn.jsdelivr.net/npm/flowbite@4.0.1/dist/flowbite.min.css"
      rel="stylesheet"
    />
  </head>
  <body></body>
</html>

# %% [markdown]
# Ahora, integrar dentro de la etiqueta `<body> </body>` el script de Flowbite:
#
# Script de Flowbite:
#
# ```
# https://flowbite.com/docs/getting-started/quickstart/

# %%
<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0" />
    <script src="https://cdn.tailwindcss.com"></script>
    <link
      href="https://cdn.jsdelivr.net/npm/flowbite@4.0.1/dist/flowbite.min.css"
      rel="stylesheet"
    />
  </head>
  <body>
    <script src="https://cdn.jsdelivr.net/npm/flowbite@4.0.1/dist/flowbite.min.js"></script>
  </body>
</html>

# %% [markdown]
# ▶ *Abrir en Live Server para verificar.*
#
# ---

# %% [markdown]
# ## 2. HEADER (NAVBAR)
#
# 📌 Desde Flowbite → Components → Navbar
# 👉 [https://flowbite.com/docs/components/navbar/](https://flowbite.com/docs/components/navbar/)
#
# ### Buscar la interfaz mas parecida a esta:

# %% [markdown]
# Pegar el código y ajustar:
#
# <span> Digital Twins Lab</span>
#
# <a href="#">Inicio</a>
# <a href="#">Sobre el proyecto</a>
# <a href="#">Investigación</a>
# <a href="#">Contacto</a>
#
# <button>Agenda una demo</button>

# %% [markdown]
# Código actualizado

# %%
    <nav
      class="bg-neutral-primary fixed w-full z-20 top-0 start-0 border-b border-default"
    >
      <div
        class="max-w-screen-xl flex flex-wrap items-center justify-between mx-auto p-4"
      >
        <a href="#" class="flex items-center space-x-3 rtl:space-x-reverse">
          <span
            class="self-center text-xl text-heading font-semibold whitespace-nowrap"
            >Digital Twins Lab</span
          >
        </a>
        <div class="flex md:order-2 space-x-3 md:space-x-0 rtl:space-x-reverse">
          <button
            type="button"
            class="text-white bg-brand hover:bg-brand-strong box-border border border-transparent focus:ring-4 focus:ring-brand-medium shadow-xs font-medium leading-5 rounded-base text-sm px-3 py-2 focus:outline-none"
          >
            Agenda tu demo
          </button>
        </div>
        <div
          class="items-center justify-between hidden w-full md:flex md:w-auto md:order-1"
          id="navbar-sticky"
        >
          <ul
            class="flex flex-col p-4 md:p-0 mt-4 font-medium border border-default rounded-base bg-neutral-secondary-soft md:space-x-8 rtl:space-x-reverse md:flex-row md:mt-0 md:border-0 md:bg-neutral-primary"
          >
            <li>
              <a
                href="#"
                class="block py-2 px-3 text-white bg-brand rounded-sm md:bg-transparent md:text-fg-brand md:p-0"
                aria-current="page"
                >Inicio</a
              >
            </li>
            <li>
              <a
                href="#"
                class="block py-2 px-3 text-heading rounded hover:bg-neutral-tertiary md:hover:bg-transparent md:border-0 md:hover:text-fg-brand md:p-0 md:dark:hover:bg-transparent"
                >Sobre el proyecto</a
              >
            </li>
            <li>
              <a
                href="#"
                class="block py-2 px-3 text-heading rounded hover:bg-neutral-tertiary md:hover:bg-transparent md:border-0 md:hover:text-fg-brand md:p-0 md:dark:hover:bg-transparent"
                >Investigación</a
              >
            </li>
            <li>
              <a
                href="#"
                class="block py-2 px-3 text-heading rounded hover:bg-neutral-tertiary md:hover:bg-transparent md:border-0 md:hover:text-fg-brand md:p-0 md:dark:hover:bg-transparent"
                >Contacto</a
              >
            </li>
          </ul>
        </div>
      </div>
    </nav>

# %% [markdown]
# No se ven elementos de la aplicación web?... Crea el archivo de `tailwind.config.js` en la raiz de la aplicación

# %%
tailwind.config = {
  theme: {
    extend: {
      colors: {
        brand: "#3b82f6",
        "brand-strong": "#2563eb",
        "brand-medium": "#93c5fd",
        "neutral-primary": "#ffffff",
        "neutral-secondary-soft": "#f3f4f6",
        "neutral-tertiary": "#e5e7eb",
        heading: "#111827",
        body: "#6b7280",
        "fg-brand": "#3b82f6",
      },
      borderRadius: {
        base: "0.5rem",
      },
      boxShadow: {
        xs: "0 1px 2px 0 rgb(0 0 0 / 0.05)",
      },
      borderColor: {
        default: "#e5e7eb",
      },
    },
  },
};

# %% [markdown]
# Inserta el siguiente script en la etiqueta `<head> </head>`

# %%
<script src="tailwind.config.js"></script>

# %% [markdown]
# ## 3. FORMULARIO principal
#
# 📌 Desde Flowbite → Components → Forms → Floating Input 🡢 adaptado al ejemplo
#
# 👉 [https://flowbite.com/docs/forms/input-field/](https://flowbite.com/docs/forms/input-field/)
#
#
# Ubicamos el componente que tenga mas parecido con lo solicitado o deseado y pegamos.
#
# Pero primer... Agregamos una sección en el html y dentro el codigo del formulario

# %%
<section> 
<h2> Agenda tu demo</h2>
<form>
    <div class="grid gap-6 mb-6 md:grid-cols-2">
        <div>
            <label for="first_name" class="block mb-2.5 text-sm font-medium text-heading">Nombre completo</label>
            <input type="text" id="first_name" class="bg-neutral-secondary-medium border border-default-medium text-heading text-sm rounded-base focus:ring-brand focus:border-brand block w-full px-3 py-2.5 shadow-xs placeholder:text-body" placeholder="Ej: Luis Molero" requerido />
        </div>
        <div class="mb-6">
            <label for="email" class="block mb-2.5 text-sm font-medium text-heading">Correo institucional</label>
            <input type="email" id="email" class="bg-neutral-secondary-medium border border-default-medium text-heading text-sm rounded-base focus:ring-brand focus:border-brand block w-full px-3 py-2.5 shadow-xs placeholder:text-body" placeholder="Ej: lmolero@ucompensar.edu.co" requerido />
        </div>
        <div>
            <label for="company" class="block mb-2.5 text-sm font-medium text-heading">Organización</label>
            <input type="text" id="company" class="bg-neutral-secondary-medium border border-default-medium text-heading text-sm rounded-base focus:ring-brand focus:border-brand block w-full px-3 py-2.5 shadow-xs placeholder:text-body" placeholder="" requerido />
        </div>
        
        <div>
            <label for="rol" class="block mb-2.5 text-sm font-medium text-heading">Rol</label>
            <input type="text" id="rol" class="bg-neutral-secondary-medium border border-default-medium text-heading text-sm rounded-base focus:ring-brand focus:border-brand block w-full px-3 py-2.5 shadow-xs placeholder:text-body" placeholder="" requerido />
        </div>
        
        <div>
            <label for="comentarios" class="block mb-2.5 text-sm font-medium text-heading">Comentarios</label>
            <input type="text" id="comentarios" class="bg-neutral-secondary-medium border border-default-medium text-heading text-base rounded-base focus:ring-brand focus:border-brand block w-full px-4 py-3.5 shadow-xs placeholder:text-body" placeholder="" required />
        </div>

<button type="submit" class="text-white bg-brand box-border border border-transparent hover:bg-brand-strong focus:ring-4 focus:ring-brand-medium shadow-xs font-medium leading-5 rounded-base text-sm px-4 py-2.5 focus:outline-none">Enviar solicitud</button>
</section>

# %% [markdown]
# # 4. FOOTER
#
# 📌 Desde Flowbite → Components → Footer
# 👉 [https://flowbite.com/docs/components/footer/](https://flowbite.com/docs/components/footer/)
#
# Ubicamos el componente que tenga mas parecido con lo solicitado o deseado y pegamos.

# %%
<footer class="bg-neutral-primary-soft">
      <hr class="my-6 border-default sm:mx-auto lg:my-8" />
      <div class="sm:flex sm:items-center sm:justify-between">
          <span class="text-sm text-body sm:text-center">© 2023 <a href="https://flowbite.com/" class="hover:underline">Flowbite™</a>. All Rights Reserved.
          </span>
          <div class="flex mt-4 sm:justify-center sm:mt-0">
            <a href="#" class="text-body hover:text-heading">
                <svg class="w-5 h-5" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="24" height="24" fill="currentColor" viewBox="0 0 24 24"><path fill-rule="evenodd" d="M13.135 6H15V3h-1.865a4.147 4.147 0 0 0-4.142 4.142V9H7v3h2v9.938h3V12h2.021l.592-3H12V6.591A.6.6 0 0 1 12.592 6h.543Z" clip-rule="evenodd"/></svg>
                <span class="sr-only">Facebook page</span>
            </a>
            <a href="#" class="text-body hover:text-heading ms-5">
                <svg class="w-5 h-5" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="24" height="24" fill="currentColor" viewBox="0 0 24 24"><path d="M18.942 5.556a16.3 16.3 0 0 0-4.126-1.3 12.04 12.04 0 0 0-.529 1.1 15.175 15.175 0 0 0-4.573 0 11.586 11.586 0 0 0-.535-1.1 16.274 16.274 0 0 0-4.129 1.3 17.392 17.392 0 0 0-2.868 11.662 15.785 15.785 0 0 0 4.963 2.521c.41-.564.773-1.16 1.084-1.785a10.638 10.638 0 0 1-1.706-.83c.143-.106.283-.217.418-.331a11.664 11.664 0 0 0 10.118 0c.137.114.277.225.418.331-.544.328-1.116.606-1.71.832a12.58 12.58 0 0 0 1.084 1.785 16.46 16.46 0 0 0 5.064-2.595 17.286 17.286 0 0 0-2.973-11.59ZM8.678 14.813a1.94 1.94 0 0 1-1.8-2.045 1.93 1.93 0 0 1 1.8-2.047 1.918 1.918 0 0 1 1.8 2.047 1.929 1.929 0 0 1-1.8 2.045Zm6.644 0a1.94 1.94 0 0 1-1.8-2.045 1.93 1.93 0 0 1 1.8-2.047 1.919 1.919 0 0 1 1.8 2.047 1.93 1.93 0 0 1-1.8 2.045Z"/></svg>
                <span class="sr-only">Discord community</span>
            </a>
            <a href="#" class="text-body hover:text-heading ms-5">
            <svg class="w-5 h-5" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="24" height="24" fill="currentColor" viewBox="0 0 24 24"><path d="M13.795 10.533 20.68 2h-3.073l-5.255 6.517L7.69 2H1l7.806 10.91L1.47 22h3.074l5.705-7.07L15.31 22H22l-8.205-11.467Zm-2.38 2.95L9.97 11.464 4.36 3.627h2.31l4.528 6.317 1.443 2.02 6.018 8.409h-2.31l-4.934-6.89Z"/></svg>
            <span class="sr-only">Twitter page</span>
            </a>
            <a href="#" class="text-body hover:text-heading ms-5">
                <svg class="w-5 h-5" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="24" height="24" fill="currentColor" viewBox="0 0 24 24"><path fill-rule="evenodd" d="M12.006 2a9.847 9.847 0 0 0-6.484 2.44 10.32 10.32 0 0 0-3.393 6.17 10.48 10.48 0 0 0 1.317 6.955 10.045 10.045 0 0 0 5.4 4.418c.504.095.683-.223.683-.494 0-.245-.01-1.052-.014-1.908-2.78.62-3.366-1.21-3.366-1.21a2.711 2.711 0 0 0-1.11-1.5c-.907-.637.07-.621.07-.621.317.044.62.163.885.346.266.183.487.426.647.71.135.253.318.476.538.655a2.079 2.079 0 0 0 2.37.196c.045-.52.27-1.006.635-1.37-2.219-.259-4.554-1.138-4.554-5.07a4.022 4.022 0 0 1 1.031-2.75 3.77 3.77 0 0 1 .096-2.713s.839-.275 2.749 1.05a9.26 9.26 0 0 1 5.004 0c1.906-1.325 2.74-1.05 2.74-1.05.37.858.406 1.828.101 2.713a4.017 4.017 0 0 1 1.029 2.75c0 3.939-2.339 4.805-4.564 5.058a2.471 2.471 0 0 1 .679 1.897c0 1.372-.012 2.477-.012 2.814 0 .272.18.592.687.492a10.05 10.05 0 0 0 5.388-4.421 10.473 10.473 0 0 0 1.313-6.948 10.32 10.32 0 0 0-3.39-6.165A9.847 9.847 0 0 0 12.007 2Z" clip-rule="evenodd"/></svg>
                <span class="sr-only">GitHub account</span>
            </a>
            <a href="#" class="text-body hover:text-heading ms-5">
                <svg class="w-5 h-5" aria-hidden="true" xmlns="http://www.w3.org/2000/svg" width="24" height="24" fill="currentColor" viewBox="0 0 24 24"><path fill-rule="evenodd" d="M12 2a10 10 0 1 0 10 10A10.009 10.009 0 0 0 12 2Zm6.613 4.614a8.523 8.523 0 0 1 1.93 5.32 20.093 20.093 0 0 0-5.949-.274c-.059-.149-.122-.292-.184-.441a23.879 23.879 0 0 0-.566-1.239 11.41 11.41 0 0 0 4.769-3.366ZM10 3.707a8.82 8.82 0 0 1 2-.238 8.5 8.5 0 0 1 5.664 2.152 9.608 9.608 0 0 1-4.476 3.087A45.755 45.755 0 0 0 10 3.707Zm-6.358 6.555a8.57 8.57 0 0 1 4.73-5.981 53.99 53.99 0 0 1 3.168 4.941 32.078 32.078 0 0 1-7.9 1.04h.002Zm2.01 7.46a8.51 8.51 0 0 1-2.2-5.707v-.262a31.641 31.641 0 0 0 8.777-1.219c.243.477.477.964.692 1.449-.114.032-.227.067-.336.1a13.569 13.569 0 0 0-6.942 5.636l.009.003ZM12 20.556a8.508 8.508 0 0 1-5.243-1.8 11.717 11.717 0 0 1 6.7-5.332.509.509 0 0 1 .055-.02 35.65 35.65 0 0 1 1.819 6.476 8.476 8.476 0 0 1-3.331.676Zm4.772-1.462A37.232 37.232 0 0 0 15.113 13a12.513 12.513 0 0 1 5.321.364 8.56 8.56 0 0 1-3.66 5.73h-.002Z" clip-rule="evenodd"/></svg>
                <span class="sr-only">Dribbble account</span>
            </a>
          </div>
      </div>
    </div>
</footer>

# %% [markdown]
# 📌 Prompt profesional para mejora de interfaz (versión actualizada)
#
# El proyecto ya está completamente desarrollado. Necesito que optimices la interfaz siguiendo buenas prácticas de diseño y usabilidad, sin alterar la estructura funcional del código.
#
# Por favor, realiza los siguientes ajustes:
#
# Centra visualmente el formulario en la mitad de la aplicación (horizontalmente, y verticalmente si es conveniente).
#
# Mejora la visibilidad y estilo del botón "Submit" (tamaño, color, padding, hover), manteniendo coherencia con el diseño general.
#
# Destaca correctamente el título "Agenda tu demo" aumentando su tamaño y aplicando negrilla (sin romper la jerarquía visual).
#
# Ajusta el footer. Debe mantenerse visible y pegado al final de la ventana, incluso si hay poco contenido.
#
# Si es necesario, incorpora espaciados (margin/padding) para mejorar estética, proporciones y legibilidad.
#
# ✔ Explica brevemente qué cambios realizaste y por qué mejoran la experiencia visual.
# ✔ Mantén la versión de Tailwind actualmente empleada en el proyecto.
# ✔ No modifiques la funcionalidad, solo el estilo y la disposición.
#
# Si consideras otra mejora estética mínima que aporte valor (alineación, contraste, tipografía, espaciado), puedes sugerirla brevemente.

# %% [markdown]
# # 📌 **Prompt Profesional Actualizado – Refactorización y Componentización del Ejercicio de Digital Twins Lab**
#
# **Rol:** Eres un asistente experto en desarrollo frontend con HTML, Tailwind CSS y Flowbite, especializado en refactorización de interfaces, arquitectura limpia y documentación técnica para proyectos empresariales.
#
# Tu tarea es mejorar la implementación actual de la interfaz de "Digital Twins Lab", construida con **HTML + Tailwind v3 + Flowbite**, realizando una refactorización orientada a **componentes reutilizables y código limpio**, manteniendo la funcionalidad existente sin alterarla.
#
# ---
#
# ## 🎯 **Objetivos de la intervención**
#
# 1. **Organizar el código HTML en estructura modular o de componentes** (según el entorno del proyecto).
# 2. **Aplicar principios de programación limpia (Clean Code) y buenas prácticas UI/UX.**
# 3. **Optimizar los estilos y estructura utilizando únicamente utilidades de Tailwind y componentes oficiales de Flowbite.**
# 4. **Mantener diseño responsivo profesional** mediante breakpoints (`sm`, `md`, `lg`, `xl`).
# 5. **Mejorar legibilidad y mantenibilidad** (espaciados, semántica HTML, clases coherentes).
#
# ---
#
# ## 📁 **Componentes a extraer y estructurar**
#
# El proyecto debe reorganizarse para contener los siguientes componentes:
#
# ```
# components/
#   ├── Header.html
#   ├── FormBookingDemo.html   (formulario "Agenda tu demo")
#   ├── Footer.html
# ```
#
# ---
#
# ## 🔒 **Requerimientos técnicos**
#
# 1. **Tailwind CSS + Flowbite como única fuente de estilos.**
#
#    * No utilizar CSS personalizado ni librerías adicionales.
# 2. **Cumplir normas profesionales:**
#
#    * `OWASP Secure Coding Practices` (sin `innerHTML`, `eval`, ni inserción dinámica insegura).
#    * `Clean Code` aplicado a arquitectura frontend (sin duplicaciones, estructura clara).
# 3. Optimización UI:
#
#    * Verifica que el formulario esté centrado correctamente.
#    * Asegura que **"Agenda tu demo"** tenga jerarquía visual adecuada.
#    * El botón **Submit** debe estar optimizado estéticamente y funcionalmente.
#    * El **footer debe posicionarse correctamente y ser visible.**
# 4. Permitir fácil mantenimiento y escalación del layout.
#
# ---
#
# ## 📢 Formato esperado de respuesta
#
# ✔ Propuesta de estructura de carpetas/componentes
# ✔ Fragmentos de código refactorizados
# ✔ Explicación corta y técnica de cada mejora
# ✔ Sugerencias opcionales para escalabilidad futura
#
# ---
#
# 💬 **Iniciar ahora analizando el código actual, detectando patrones repetibles y proponiendo una estructura de componentes modular.**
# Puedes comenzar con una breve evaluación técnica antes de sugerir el refactoring.
